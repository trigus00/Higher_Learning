# %% [markdown]
# ## Import Dependencies

# %%
# Dependencies
# ----------------------------------
# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

import psycopg2 as pg
import numpy as np
import pandas as pd

import sys
sys.path.append("..")
from cred.cred_user import username
from cred.cred_p import pgpass
from cred.cred_host import host_loc
from cred.cred_port import cred_port

db = "higher_learning"

# %% [markdown]
# ## Kaggle: Crime and Incarceration in the United States: 21st century state crime and prison custody statistics

# %%
inc_data = "data/kaggle_corr/crime_and_incarceration_by_state.csv"
inc_df = pd.read_csv(inc_data)
inc_df.head()
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                    NaN
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0              NaN               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# 1                379.0       1369.0           NaN   5584.0      12250.0
# 2                 39.0        501.0           NaN    514.0       2681.0
# 3                400.0       1518.0           NaN   8868.0      17889.0
# 4                148.0        892.0           NaN   2181.0       8969.0
#
#    property_crime_total  burglary   larceny  vehicle_theft
# 0                   NaN       NaN       NaN            NaN
# 1              173253.0   40642.0  119992.0        12619.0
# 2               23160.0    3847.0   16695.0         2618.0
# 3              293874.0   54821.0  186850.0        52203.0
# 4               99106.0   22196.0   69590.0         7320.0

# %%
inc_df.columns
# Out:
# Index(['jurisdiction', 'includes_jails', 'year', 'prisoner_count',
#        'crime_reporting_change', 'crimes_estimated', 'state_population',
#        'violent_crime_total', 'murder_manslaughter', 'rape_legacy',
#        'rape_revised', 'robbery', 'agg_assault', 'property_crime_total',
#        'burglary', 'larceny', 'vehicle_theft'],
#       dtype='object')

# %%
incarceration_df = inc_df[['jurisdiction', 'year', 'prisoner_count', 'state_population']].copy()
incarceration_df.columns = ['state', 'year', 'prisoner_count', 'state_population']

# %%
incarceration_df['year'] = incarceration_df['year'].astype(int, inplace = True)
incarceration_df['prisoner_count'] = incarceration_df['prisoner_count'].astype(int, inplace = True)

# %%
incarceration_df = incarceration_df[incarceration_df['year']>2005]
incarceration_df = incarceration_df[incarceration_df['state']!='FEDERAL']

# %%
incarceration_df['year_state'] = incarceration_df['year'].map(str) + '_' + incarceration_df['state'].map(str)

# %%
inc_na = incarceration_df[incarceration_df['state_population'].isnull()].copy()

# %%
inc_na
# Out:
#         state  year  prisoner_count  state_population     year_state
# 746  NEW YORK  2015           51485               NaN  2015_NEW YORK

# %%
inc_na_idx = (incarceration_df[incarceration_df['state_population'].isnull()].index[0]).copy()
print(inc_na_idx)
# Out:
# 746

# %%
# 2015 NY Population 
# https://population.us/ny/
# https://www.health.ny.gov/statistics/vital_statistics/2015/table02.htm
incarceration_df.update(incarceration_df.loc[[inc_na_idx]].fillna('19795791'))

# %%
inc_check_na = incarceration_df[(incarceration_df.state=='NEW YORK') & (incarceration_df.year == 2015)].copy()

# %%
inc_check_na
# Out:
#         state    year  prisoner_count state_population     year_state
# 746  NEW YORK  2015.0         51485.0         19795791  2015_NEW YORK

# %%
incarceration_df['state_population'] = incarceration_df['state_population'].astype(int, inplace = True)

# %%
incarceration_df.head()
# Out:
#           state    year  prisoner_count  state_population       year_state
# 256     ALABAMA  2006.0         24103.0           4599030     2006_ALABAMA
# 257      ALASKA  2006.0          5052.0            670053      2006_ALASKA
# 258     ARIZONA  2006.0         35752.0           6166318     2006_ARIZONA
# 259    ARKANSAS  2006.0         12854.0           2810872    2006_ARKANSAS
# 260  CALIFORNIA  2006.0        172298.0          36457549  2006_CALIFORNIA

# %%
incarceration_df.tail()
# Out:
#              state    year  prisoner_count  state_population  \
# 811       VIRGINIA  2016.0         29882.0           8414380
# 812     WASHINGTON  2016.0         17228.0           7280934
# 813  WEST VIRGINIA  2016.0          5899.0           1828637
# 814      WISCONSIN  2016.0         23163.0           5772917
# 815        WYOMING  2016.0          2352.0            584910
#
#              year_state
# 811       2016_VIRGINIA
# 812     2016_WASHINGTON
# 813  2016_WEST VIRGINIA
# 814      2016_WISCONSIN
# 815        2016_WYOMING

# %% [markdown]
# ## Kaggle: U.S. Education Datasets: Unification Project: K-12 financial, enrollment, and achievement data in one place

# %%
ed_data = "data/kaggle_ed/states_all_extended.csv"
ed_df = pd.read_csv(ed_data)
ed_df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
#    ...  GRADES_4_TRF  GRADES_8_TRF  GRADES_12_TRF  GRADES_1_8_TRF  \
# 0  ...           NaN           NaN            NaN             NaN
# 1  ...           NaN           NaN            NaN             NaN
# 2  ...           NaN           NaN            NaN             NaN
# 3  ...           NaN           NaN            NaN             NaN
# 4  ...           NaN           NaN            NaN             NaN
#
#    GRADES_9_12_TRF  GRADES_ALL_TRF  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  \
# 0              NaN             NaN        208.327876        252.187522
# 1              NaN             NaN               NaN               NaN
# 2              NaN             NaN        215.253932        265.366278
# 3              NaN             NaN        210.206028        256.312090
# 4              NaN             NaN        208.398961        260.892247
#
#    AVG_READING_4_SCORE  AVG_READING_8_SCORE
# 0           207.963517                  NaN
# 1                  NaN           258.859712
# 2           206.212716           262.169895
# 3           208.634458           264.619665
# 4           196.764414                  NaN
#
# [5 rows x 193 columns]

# %%
ed_df.columns
# Out:
# Index(['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_REVENUE',
#        'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE',
#        'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE',
#        ...
#        'GRADES_4_TRF', 'GRADES_8_TRF', 'GRADES_12_TRF', 'GRADES_1_8_TRF',
#        'GRADES_9_12_TRF', 'GRADES_ALL_TRF', 'AVG_MATH_4_SCORE',
#        'AVG_MATH_8_SCORE', 'AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'],
#       dtype='object', length=193)

# %%
ed_df_state_list = ed_df['STATE'].value_counts()

# %%
ed_df_state_list.describe()
# Out:
# count    80.000000
# mean     18.650000
# std      10.901283
# min       1.000000
# 25%       4.000000
# 50%      26.000000
# 75%      26.000000
# max      29.000000
# Name: STATE, dtype: float64

# %%
ed_df_state_list[51:80]
# Out:
# PUERTO_RICO                                 23
# GUAM                                        23
# AMERICAN_SAMOA                              22
# VIRGIN_ISLANDS                              22
# NORTHERN_MARIANAS                           14
# DOD_OVERSEAS                                 8
# DOD_DOMESTIC                                 8
# BUREAU_OF_INDIAN_AFFAIRS                     6
# BI                                           4
# DD                                           4
# COMMONWEALTH_OF_MARIANAS                     3
# NORTHERN_MARIANA_ISLANDS                     3
# BIE                                          2
# DOD_-_DOMESTIC                               2
# BUREAU_OF_INDIAN_EDUCATION                   2
# DOD_-_OVERSEAS                               2
# AS                                           1
# DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY     1
# PR                                           1
# DOD                                          1
# VI                                           1
# GU                                           1
# DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)         1
# MP                                           1
# DOD_-_FOREIGN                                1
# U.S._VIRGIN_ISLANDS                          1
# BUREAU_OF_INDIAN_EDUCATIO                    1
# MARIANAS                                     1
# DEPARTMENT_OF_DEFENSE                        1
# Name: STATE, dtype: int64

# %%
ed_df_states_exclude = ['DISTRICT_OF_COLUMBIA', 'GUAM', 'PUERTO_RICO', 'AMERICAN_SAMOA','VIRGIN_ISLANDS', 'NORTHERN_MARIANAS',
                  'DOD_OVERSEAS', 'DOD_DOMESTIC', 'BUREAU_OF_INDIAN_AFFAIRS', 'BI', 'DD', 'COMMONWEALTH_OF_MARIANAS', 'NORTHERN_MARIANA_ISLANDS', 
                  'DOD_-_OVERSEAS', 'BIE', 'DOD_-_DOMESTIC', 'BUREAU_OF_INDIAN_EDUCATION', 'VI',
                  'DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)', 'MARIANAS', 'AS', 'PR', 'GU', 'DEPARTMENT_OF_DEFENSE',
                  'DOD_-_FOREIGN', 'BUREAU_OF_INDIAN_EDUCATIO', 'MP', 'DOD', 'DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY',
                  'U.S._VIRGIN_ISLANDS'
                 ]

# %%
ed_df = ed_df[~ed_df.STATE.isin(ed_df_states_exclude)]

# %%
ed_df['STATE'].describe()
# Out:
# count         1302
# unique          50
# top       VIRGINIA
# freq            28
# Name: STATE, dtype: object

# %%
ed_enroll_exp_df = ed_df[['PRIMARY_KEY', 'STATE', 'YEAR', 'ENROLL', 'TOTAL_EXPENDITURE']].copy()
ed_enroll_exp_df.columns = ['year_state', 'state', 'year', 'enrollment', 'total_expenditure']

# %%
ed_enroll_exp_df["enrollment"].fillna(0, inplace=True)
ed_enroll_exp_df["total_expenditure"].fillna(0, inplace=True)

# %%
ed_enroll_exp_df['year'] = ed_enroll_exp_df['year'].astype(int, inplace = True)
ed_enroll_exp_df['enrollment'] = ed_enroll_exp_df['enrollment'].astype(int, inplace = True)
ed_enroll_exp_df['total_expenditure'] = ed_enroll_exp_df['total_expenditure'].astype(int, inplace = True)

# %%
ed_enroll_exp_df = ed_enroll_exp_df[(ed_enroll_exp_df.year>2005) & (ed_enroll_exp_df.year<2017)]

# %%
ed_enroll_exp_df['state'].describe()
# Out:
# count          552
# unique          50
# top       VIRGINIA
# freq            13
# Name: state, dtype: object

# %%
ed_enroll_exp_df['state'].nunique()
# Out:
# 50

# %%
ed_enroll_exp_df['state'] = ed_enroll_exp_df['state'].str.replace('_',' ')

# %%
ed_enroll_exp_df['year_state'].value_counts()
# Out:
# 2008_VIRGINIA          3
# 2009_WEST_VIRGINIA     1
# 2006_ILLINOIS          1
# 2011_MAINE             1
# 2014_CALIFORNIA        1
# 2016_OKLAHOMA          1
# 2010_NEW_YORK          1
# 2015_NEBRASKA          1
# 2006_KENTUCKY          1
# 2014_IDAHO             1
# 2013_COLORADO          1
# 2008_COLORADO          1
# 2016_WEST_VIRGINIA     1
# 2013_NEW_JERSEY        1
# 2007_MINNESOTA         1
# 2015_FLORIDA           1
# 2011_ARKANSAS          1
# 2015_NEW_JERSEY        1
# 2008_ARKANSAS          1
# 2013_INDIANA           1
# 2013_SOUTH_DAKOTA      1
# 2011_SOUTH_DAKOTA      1
# 2008_RHODE_ISLAND      1
# 2006_ALASKA            1
# 2006_NEW_YORK          1
# 2011_GEORGIA           1
# 2009_LOUISIANA         1
# 2011_WEST_VIRGINIA     1
# 2014_VERMONT           1
# 2011_WASHINGTON        1
#                       ..
# 2015_NEW_MEXICO        1
# 2012_LOUISIANA         1
# 2010_IOWA              1
# 2010_MINNESOTA         1
# 2012_WISCONSIN         1
# 2010_KENTUCKY          1
# 2008_MONTANA           1
# 2012_GEORGIA           1
# 2012_COLORADO          1
# 2016_MARYLAND          1
# 2010_SOUTH_CAROLINA    1
# 2008_NEW_YORK          1
# 2016_FLORIDA           1
# 2010_MICHIGAN          1
# 2009_SOUTH_DAKOTA      1
# 2013_ARKANSAS          1
# 2009_RHODE_ISLAND      1
# 2009_NEVADA            1
# 2014_NORTH_CAROLINA    1
# 2006_MICHIGAN          1
# 2009_VIRGINIA          1
# 2011_VIRGINIA          1
# 2013_TEXAS             1
# 2015_MISSISSIPPI       1
# 2016_MISSOURI          1
# 2010_DELAWARE          1
# 2006_NEBRASKA          1
# 2006_TEXAS             1
# 2013_FLORIDA           1
# 2007_HAWAII            1
# Name: year_state, Length: 550, dtype: int64

# %%
ed_duplicates = ed_enroll_exp_df[(ed_enroll_exp_df.year_state=='2008_VIRGINIA')]

# %%
ed_duplicates.head()
# Out:
#         year_state     state  year  enrollment  total_expenditure
# 863  2008_VIRGINIA  VIRGINIA  2008     1230857           15236306
# 864  2008_VIRGINIA  VIRGINIA  2008     1230857           15236306
# 865  2008_VIRGINIA  VIRGINIA  2008     1230857           15236306

# %%
ed_enroll_exp_df.drop_duplicates(subset ="year_state", keep = 'first', inplace = True)

# %%
ed_duplicates_post = ed_enroll_exp_df[(ed_enroll_exp_df.year_state=='2008_VIRGINIA')]

# %%
ed_duplicates_post.head()
# Out:
#         year_state     state  year  enrollment  total_expenditure
# 863  2008_VIRGINIA  VIRGINIA  2008     1230857           15236306

# %%
ed_enroll_exp_df.head()
# Out:
#           year_state       state  year  enrollment  total_expenditure
# 714     2006_ALABAMA     ALABAMA  2006      743265            6591429
# 715      2006_ALASKA      ALASKA  2006      132893            1817656
# 716     2006_ARIZONA     ARIZONA  2006      947266            7934177
# 717    2006_ARKANSAS    ARKANSAS  2006      472609            4343877
# 718  2006_CALIFORNIA  CALIFORNIA  2006     6295994           68722432

# %%
ed_enroll_exp_df.tail()
# Out:
#               year_state          state  year  enrollment  total_expenditure
# 1275       2016_VIRGINIA       VIRGINIA  2016     1283493           16497520
# 1276     2016_WASHINGTON     WASHINGTON  2016     1083973           15253296
# 1277  2016_WEST_VIRGINIA  WEST VIRGINIA  2016      276764            3366566
# 1278      2016_WISCONSIN      WISCONSIN  2016      857736           11787535
# 1279        2016_WYOMING        WYOMING  2016       94511            2034229

# %% [markdown]
# ## Urban Institute: State and Local Finance Data Query System: cost per prisoner by state (2006-2016)

# %%
pr_exp_data = "data/urbaninstitute/cost per prisoner by state (2006-2016).csv"
pr_exp_df = pd.read_csv(pr_exp_data)
pr_exp_df.head()
# Out:
#    Level: State and Local Unnamed: 1                    Unnamed: 2  \
# 0  Unit:Total (thousands)    Nominal                           NaN
# 1                   State       Year  (E021) Total Correct-Dir Exp
# 2           United States       2006                  $62,642,834
# 3           United States       2007                  $68,035,382
# 4           United States       2008                  $72,752,623
#
#                       Unnamed: 3                    Unnamed: 4
# 0                            NaN                           NaN
# 1  (E022) Total Correct-Cur Oper  (E023) Total Correct-Cap Out
# 2                   $60,171,656                    $2,471,178
# 3                   $64,811,380                    $3,224,002
# 4                   $69,199,149                    $3,553,474

# %%
pr_exp_df.tail()
# Out:
#     Level: State and Local                                         Unnamed: 1  \
# 571                Wyoming                                               2014
# 572                Wyoming                                               2015
# 573                Wyoming                                               2016
# 574                    NaN                                                NaN
# 575  Observations with N/A   missing years or zero values should be checke...
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4
# 571  $210,034   $207,690     $2,344
# 572  $213,887   $210,756     $3,131
# 573  $214,564   $213,090     $1,474
# 574        NaN        NaN        NaN
# 575        NaN        NaN        NaN

# %%
pr_exp_df.columns
# Out:
# Index(['Level: State and Local', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4'],
#       dtype='object')

# %%
pr_exp_df['Level: State and Local'].describe()
# Out:
# count      575
# unique      55
# top       Iowa
# freq        11
# Name: Level: State and Local, dtype: object

# %%
pr_exp_df['Level: State and Local'].value_counts()
# Out:
# Iowa                      11
# United States             11
# New Jersey                11
# Arkansas                  11
# Texas                     11
# Hawaii                    11
# Florida                   11
# Michigan                  11
# Mississippi               11
# Colorado                  11
# New Mexico                11
# Nevada                    11
# Missouri                  11
# Ohio                      11
# Virginia                  11
# California                11
# Georgia                   11
# New Hampshire             11
# Kentucky                  11
# Utah                      11
# Wisconsin                 11
# Massachusetts             11
# North Dakota              11
# Wyoming                   11
# New York                  11
# Connecticut               11
# South Dakota              11
# Tennessee                 11
# Vermont                   11
# Louisiana                 11
# Nebraska                  11
# South Carolina            11
# Kansas                    11
# Arizona                   11
# Delaware                  11
# West Virginia             11
# Pennsylvania              11
# Rhode Island              11
# Maine                     11
# Alaska                    11
# Idaho                     11
# Alabama                   11
# Washington                11
# North Carolina            11
# Oregon                    11
# DC                        11
# Illinois                  11
# Maryland                  11
# Indiana                   11
# Minnesota                 11
# Montana                   11
# Oklahoma                  11
# State                      1
# Unit:Total (thousands)     1
# Observations with N/A      1
# Name: Level: State and Local, dtype: int64

# %%
pr_exp_states_exclude = ['United States', 'DC', 'Unit:Total (thousands)', 'Observations with N/A', 'State']
pr_exp_df = pr_exp_df[~pr_exp_df['Level: State and Local'].isin(pr_exp_states_exclude)]

# %%
pr_exp_df['Level: State and Local'].describe()
# Out:
# count      550
# unique      50
# top       Iowa
# freq        11
# Name: Level: State and Local, dtype: object

# %%
pr_exp_df.head()
# Out:
#    Level: State and Local Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 13                Alabama       2006  $626,112   $597,654    $28,458
# 14                Alabama       2007  $764,056   $661,016   $103,040
# 15                Alabama       2008  $704,294   $682,245    $22,049
# 16                Alabama       2009  $741,164   $710,132    $31,032
# 17                Alabama       2010  $727,653   $722,513     $5,140

# %%
prisoner_exp_df = pr_exp_df.drop(['Unnamed: 3', 'Unnamed: 4'], axis=1).copy()

# %%
prisoner_exp_df.head()
# Out:
#    Level: State and Local Unnamed: 1 Unnamed: 2
# 13                Alabama       2006  $626,112
# 14                Alabama       2007  $764,056
# 15                Alabama       2008  $704,294
# 16                Alabama       2009  $741,164
# 17                Alabama       2010  $727,653

# %%
prisoner_exp_df.columns = ['state', 'year', 'total_expenditure']

# %%
prisoner_exp_df.head()
# Out:
#       state  year total_expenditure
# 13  Alabama  2006         $626,112
# 14  Alabama  2007         $764,056
# 15  Alabama  2008         $704,294
# 16  Alabama  2009         $741,164
# 17  Alabama  2010         $727,653

# %%
prisoner_exp_df.tail()
# Out:
#        state  year total_expenditure
# 570  Wyoming  2013         $213,000
# 571  Wyoming  2014         $210,034
# 572  Wyoming  2015         $213,887
# 573  Wyoming  2016         $214,564
# 574      NaN   NaN               NaN

# %%
prisoner_exp_df = prisoner_exp_df.dropna()

# %%
prisoner_exp_df.tail()
# Out:
#        state  year total_expenditure
# 569  Wyoming  2012         $215,414
# 570  Wyoming  2013         $213,000
# 571  Wyoming  2014         $210,034
# 572  Wyoming  2015         $213,887
# 573  Wyoming  2016         $214,564

# %%
prisoner_exp_df['year'] = prisoner_exp_df['year'].astype(int, inplace = True)

# %%
prisoner_exp_df['total_expenditure'] = prisoner_exp_df['total_expenditure'].str.replace('$','') 
prisoner_exp_df['total_expenditure'] = prisoner_exp_df['total_expenditure'].str.replace(' ','') 
prisoner_exp_df['total_expenditure'] = prisoner_exp_df['total_expenditure'].str.replace(',','') 
prisoner_exp_df['total_expenditure'] = prisoner_exp_df['total_expenditure'].astype(int, inplace = True)

# %%
prisoner_exp_df['state'] = prisoner_exp_df['state'].str.upper()

# %%
prisoner_exp_df['year_state'] = prisoner_exp_df['year'].map(str) + '_' + prisoner_exp_df['state'].map(str)

# %%
prisoner_exp_df.head()
# Out:
#       state  year  total_expenditure    year_state
# 13  ALABAMA  2006             626112  2006_ALABAMA
# 14  ALABAMA  2007             764056  2007_ALABAMA
# 15  ALABAMA  2008             704294  2008_ALABAMA
# 16  ALABAMA  2009             741164  2009_ALABAMA
# 17  ALABAMA  2010             727653  2010_ALABAMA

# %%
prisoner_exp_df.tail()
# Out:
#        state  year  total_expenditure    year_state
# 569  WYOMING  2012             215414  2012_WYOMING
# 570  WYOMING  2013             213000  2013_WYOMING
# 571  WYOMING  2014             210034  2014_WYOMING
# 572  WYOMING  2015             213887  2015_WYOMING
# 573  WYOMING  2016             214564  2016_WYOMING

# %% [markdown]
# ## The Annie E. Casey Foundation: Kids Count Data Center: Fourth grade reading achievement levels in the United States

# %%
fourth_grade_rd_data = "data/kidscount/Fourth grade reading achievement levels.xlsx"
fourth_grade_rd_df = pd.read_excel(fourth_grade_rd_data)
fourth_grade_rd_df.head()
# Out:
#   LocationType       Location       Achievement Level  TimeFrame DataFormat  \
# 0       Nation  United States             Below basic       2002    Percent
# 1       Nation  United States       At or above basic       2002    Percent
# 2       Nation  United States        Below proficient       2002    Percent
# 3       Nation  United States  At or above proficient       2002    Percent
# 4       Nation  United States             Below basic       2003    Percent
#
#    Data
# 0  0.38
# 1  0.62
# 2   0.7
# 3   0.3
# 4  0.38

# %%
fourth_grade_rd_df.columns
# Out:
# Index(['LocationType', 'Location', 'Achievement Level', 'TimeFrame',
#        'DataFormat', 'Data'],
#       dtype='object')

# %%
fourth_grade_rd_df['LocationType'].value_counts()
# Out:
# State        1800
# City           36
# Nation         36
# Territory      20
# Name: LocationType, dtype: int64

# %%
location_type_exclude =['Nation', 'City', 'Territory']
fourth_grade_rd_df = fourth_grade_rd_df[~fourth_grade_rd_df['LocationType'].isin(location_type_exclude)]
fourth_grade_read_df = fourth_grade_rd_df.drop(['LocationType', 'DataFormat'], axis=1).copy()
fourth_grade_read_df.columns = ['state', 'achievement_level', 'year', 'data']

# %%
fourth_grade_read_df['data'].nunique()
# Out:
# 71

# %%
fourth_grade_read_df['data'][0:30]
# Out:
# 36    0.37
# 37    0.63
# 38    0.69
# 39    0.31
# 40    0.33
# 41    0.67
# 42    0.69
# 43    0.31
# 44    0.38
# 45    0.62
# 46    0.72
# 47    0.28
# 48    0.35
# 49    0.65
# 50    0.71
# 51    0.29
# 52    0.38
# 53    0.62
# 54    0.71
# 55    0.29
# 56    0.35
# 57    0.65
# 58    0.69
# 59    0.31
# 60    0.47
# 61    0.53
# 62    0.78
# 63    0.22
# 64    0.48
# 65    0.52
# Name: data, dtype: object

# %%
fourth_grade_read_exclude = ['N.A.', 'S']
fourth_grade_read_df = fourth_grade_read_df[~fourth_grade_read_df['data'].isin(fourth_grade_read_exclude)]

# %%
fourth_grade_read_df['year'] = fourth_grade_read_df['year'].astype(int, inplace = True)

# %%
fourth_grade_read_df['data'] = fourth_grade_read_df['data'].str.replace('.','') 
fourth_grade_read_df['data'] = fourth_grade_read_df['data'].astype(int, inplace = True)
fourth_grade_read_df['data'] = fourth_grade_read_df['data'] / 100

# %%
fourth_grade_read_df = fourth_grade_read_df[(fourth_grade_read_df.year>2005) & (fourth_grade_read_df.year<2017)]

# %%
fourth_grade_read_df['year_state_ach_lvl'] = fourth_grade_read_df['year'].map(str) + '_' + fourth_grade_read_df['state'].map(str) + fourth_grade_read_df['achievement_level']

# %%
fourth_grade_read_df.head()
# Out:
#       state       achievement_level  year  data  \
# 40  Alabama             Below basic  2011  0.33
# 41  Alabama       At or above basic  2011  0.67
# 42  Alabama        Below proficient  2011  0.69
# 43  Alabama  At or above proficient  2011  0.31
# 44  Alabama             Below basic  2009  0.38
#
#                     year_state_ach_lvl
# 40             2011_AlabamaBelow basic
# 41       2011_AlabamaAt or above basic
# 42        2011_AlabamaBelow proficient
# 43  2011_AlabamaAt or above proficient
# 44             2009_AlabamaBelow basic

# %%
fourth_grade_read_df.tail()
# Out:
#         state       achievement_level  year  data  \
# 1819  Wyoming  At or above proficient  2009  0.33
# 1820  Wyoming             Below basic  2007  0.27
# 1821  Wyoming       At or above basic  2007  0.74
# 1822  Wyoming        Below proficient  2007  0.64
# 1823  Wyoming  At or above proficient  2007  0.36
#
#                       year_state_ach_lvl
# 1819  2009_WyomingAt or above proficient
# 1820             2007_WyomingBelow basic
# 1821       2007_WyomingAt or above basic
# 1822        2007_WyomingBelow proficient
# 1823  2007_WyomingAt or above proficient

# %% [markdown]
# ## Combined Table

# %%
merge_1_df = pd.merge(ed_enroll_exp_df, incarceration_df, on="year_state")

# %%
merge_1_df.head()
# Out:
#         year_state     state_x  year_x  enrollment  total_expenditure  \
# 0     2006_ALABAMA     ALABAMA    2006      743265            6591429
# 1      2006_ALASKA      ALASKA    2006      132893            1817656
# 2     2006_ARIZONA     ARIZONA    2006      947266            7934177
# 3    2006_ARKANSAS    ARKANSAS    2006      472609            4343877
# 4  2006_CALIFORNIA  CALIFORNIA    2006     6295994           68722432
#
#       state_y  year_y  prisoner_count  state_population
# 0     ALABAMA  2006.0         24103.0           4599030
# 1      ALASKA  2006.0          5052.0            670053
# 2     ARIZONA  2006.0         35752.0           6166318
# 3    ARKANSAS  2006.0         12854.0           2810872
# 4  CALIFORNIA  2006.0        172298.0          36457549

# %%
merge_1_df = merge_1_df[['year_state', 'state_x', 'year_x', 'enrollment', 'total_expenditure', 
                         'prisoner_count','state_population']].copy()

# %%
merge_1_df.head()
# Out:
#         year_state     state_x  year_x  enrollment  total_expenditure  \
# 0     2006_ALABAMA     ALABAMA    2006      743265            6591429
# 1      2006_ALASKA      ALASKA    2006      132893            1817656
# 2     2006_ARIZONA     ARIZONA    2006      947266            7934177
# 3    2006_ARKANSAS    ARKANSAS    2006      472609            4343877
# 4  2006_CALIFORNIA  CALIFORNIA    2006     6295994           68722432
#
#    prisoner_count  state_population
# 0         24103.0           4599030
# 1          5052.0            670053
# 2         35752.0           6166318
# 3         12854.0           2810872
# 4        172298.0          36457549

# %%
merge_1_df.columns = ['year_state', 'state', 'year', 'ed_enrollment', 'ed_total_exp', 'prisoner_count', 'state_population']

# %%
merge_1_df.head()
# Out:
#         year_state       state  year  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA  2006         743265       6591429
# 1      2006_ALASKA      ALASKA  2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA  2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS  2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA  2006        6295994      68722432
#
#    prisoner_count  state_population
# 0         24103.0           4599030
# 1          5052.0            670053
# 2         35752.0           6166318
# 3         12854.0           2810872
# 4        172298.0          36457549

# %%
merge_2_df = pd.merge(merge_1_df, prisoner_exp_df, on="year_state")

# %%
merge_2_df.head()
# Out:
#         year_state     state_x  year_x  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA    2006         743265       6591429
# 1      2006_ALASKA      ALASKA    2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA    2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS    2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA    2006        6295994      68722432
#
#    prisoner_count  state_population     state_y  year_y  total_expenditure
# 0         24103.0           4599030     ALABAMA    2006             626112
# 1          5052.0            670053      ALASKA    2006             212043
# 2         35752.0           6166318     ARIZONA    2006            1428311
# 3         12854.0           2810872    ARKANSAS    2006             446200
# 4        172298.0          36457549  CALIFORNIA    2006           10914128

# %%
merge_2_df = merge_2_df[['year_state', 'state_x', 'year_x', 'ed_enrollment', 'ed_total_exp', 
                         'prisoner_count','total_expenditure', 'state_population']].copy()

# %%
merge_2_df.head()
# Out:
#         year_state     state_x  year_x  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA    2006         743265       6591429
# 1      2006_ALASKA      ALASKA    2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA    2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS    2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA    2006        6295994      68722432
#
#    prisoner_count  total_expenditure  state_population
# 0         24103.0             626112           4599030
# 1          5052.0             212043            670053
# 2         35752.0            1428311           6166318
# 3         12854.0             446200           2810872
# 4        172298.0           10914128          36457549

# %%
merge_2_df.columns = ['year_state', 'state', 'year', 'ed_enrollment', 'ed_total_exp', 'prisoner_count', 
                      'corr_total_exp','state_population']

# %%
merge_2_df.head()
# Out:
#         year_state       state  year  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA  2006         743265       6591429
# 1      2006_ALASKA      ALASKA  2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA  2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS  2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA  2006        6295994      68722432
#
#    prisoner_count  corr_total_exp  state_population
# 0         24103.0          626112           4599030
# 1          5052.0          212043            670053
# 2         35752.0         1428311           6166318
# 3         12854.0          446200           2810872
# 4        172298.0        10914128          36457549

# %%
merge_2_df['cost_per_stu'] = merge_2_df['ed_total_exp'] / merge_2_df['ed_enrollment']
merge_2_df['stu_to_pop_percent'] = merge_2_df['ed_enrollment'] / merge_2_df['state_population']

merge_2_df['cost_per_prisoner'] = merge_2_df['corr_total_exp'] / merge_2_df['prisoner_count']
merge_2_df['prisoner_to_pop_percent'] = merge_2_df['prisoner_count'] / merge_2_df['state_population']

# %%
merge_2_df.head()
# Out:
#         year_state       state  year  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA  2006         743265       6591429
# 1      2006_ALASKA      ALASKA  2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA  2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS  2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA  2006        6295994      68722432
#
#    prisoner_count  corr_total_exp  state_population  cost_per_stu  \
# 0         24103.0          626112           4599030      8.868209
# 1          5052.0          212043            670053     13.677590
# 2         35752.0         1428311           6166318      8.375870
# 3         12854.0          446200           2810872      9.191270
# 4        172298.0        10914128          36457549     10.915263
#
#    stu_to_pop_percent  cost_per_prisoner  prisoner_to_pop_percent
# 0            0.161613          25.976517                 0.005241
# 1            0.198332          41.972090                 0.007540
# 2            0.153619          39.950520                 0.005798
# 3            0.168136          34.712930                 0.004573
# 4            0.172694          63.344485                 0.004726

# %%
ed_corr_data_df = merge_2_df.copy()

# %%
ed_corr_data_df.head()
# Out:
#         year_state       state  year  ed_enrollment  ed_total_exp  \
# 0     2006_ALABAMA     ALABAMA  2006         743265       6591429
# 1      2006_ALASKA      ALASKA  2006         132893       1817656
# 2     2006_ARIZONA     ARIZONA  2006         947266       7934177
# 3    2006_ARKANSAS    ARKANSAS  2006         472609       4343877
# 4  2006_CALIFORNIA  CALIFORNIA  2006        6295994      68722432
#
#    prisoner_count  corr_total_exp  state_population  cost_per_stu  \
# 0         24103.0          626112           4599030      8.868209
# 1          5052.0          212043            670053     13.677590
# 2         35752.0         1428311           6166318      8.375870
# 3         12854.0          446200           2810872      9.191270
# 4        172298.0        10914128          36457549     10.915263
#
#    stu_to_pop_percent  cost_per_prisoner  prisoner_to_pop_percent
# 0            0.161613          25.976517                 0.005241
# 1            0.198332          41.972090                 0.007540
# 2            0.153619          39.950520                 0.005798
# 3            0.168136          34.712930                 0.004573
# 4            0.172694          63.344485                 0.004726

# %%
ed_corr_data_df.tail()
# Out:
#           year_state       state  year  ed_enrollment  ed_total_exp  \
# 435     2016_VERMONT     VERMONT  2016          87974       2082696
# 436    2016_VIRGINIA    VIRGINIA  2016        1283493      16497520
# 437  2016_WASHINGTON  WASHINGTON  2016        1083973      15253296
# 438   2016_WISCONSIN   WISCONSIN  2016         857736      11787535
# 439     2016_WYOMING     WYOMING  2016          94511       2034229
#
#      prisoner_count  corr_total_exp  state_population  cost_per_stu  \
# 435          1735.0          137103            623354     23.673995
# 436         29882.0         2560724           8414380     12.853611
# 437         17228.0         1727579           7280934     14.071657
# 438         23163.0         1553919           5772917     13.742614
# 439          2352.0          214564            584910     21.523727
#
#      stu_to_pop_percent  cost_per_prisoner  prisoner_to_pop_percent
# 435            0.141130          79.021902                 0.002783
# 436            0.152536          85.694532                 0.003551
# 437            0.148878         100.277397                 0.002366
# 438            0.148579          67.086258                 0.004012
# 439            0.161582          91.226190                 0.004021

# %%
x = ed_corr_data_df[(ed_corr_data_df.year==2015)]

# %%
x
# Out:
#              year_state          state  year  ed_enrollment  ed_total_exp  \
# 360        2015_ALABAMA        ALABAMA  2015         734974       7501799
# 361         2015_ALASKA         ALASKA  2015         130755       2968341
# 362        2015_ARIZONA        ARIZONA  2015         944978       7902600
# 363       2015_ARKANSAS       ARKANSAS  2015         479682       5350543
# 364     2015_CALIFORNIA     CALIFORNIA  2015        6226523      78365958
# 365       2015_COLORADO       COLORADO  2015         872320       9557682
# 366    2015_CONNECTICUT    CONNECTICUT  2015         505366      10542667
# 367       2015_DELAWARE       DELAWARE  2015         121845       1975093
# 368        2015_FLORIDA        FLORIDA  2015        2743641      27277049
# 369        2015_GEORGIA        GEORGIA  2015        1717805      18501103
# 370         2015_HAWAII         HAWAII  2015         182384       2521004
# 371          2015_IDAHO          IDAHO  2015         274131       2029520
# 372       2015_ILLINOIS       ILLINOIS  2015        2047123      32410033
# 373        2015_INDIANA        INDIANA  2015        1004215      11378564
# 374           2015_IOWA           IOWA  2015         505311       6772654
# 375         2015_KANSAS         KANSAS  2015         496920       6175724
# 376       2015_KENTUCKY       KENTUCKY  2015         688475       7554887
# 377      2015_LOUISIANA      LOUISIANA  2015         661015       8437263
# 378          2015_MAINE          MAINE  2015         176176       2596180
# 379       2015_MARYLAND       MARYLAND  2015         874108      13882823
# 380  2015_MASSACHUSETTS  MASSACHUSETTS  2015         916130      16972319
# 381       2015_MICHIGAN       MICHIGAN  2015        1345009      17742903
# 382      2015_MINNESOTA      MINNESOTA  2015         807044      11969872
# 383    2015_MISSISSIPPI    MISSISSIPPI  2015         490189       4624539
# 384       2015_MISSOURI       MISSOURI  2015         892779      10540353
# 385        2015_MONTANA        MONTANA  2015         144447       1804841
# 386       2015_NEBRASKA       NEBRASKA  2015         312281       4283846
# 387         2015_NEVADA         NEVADA  2015         438948       4183085
# 388           2015_OHIO           OHIO  2015        1600222      22561728
# 389       2015_OKLAHOMA       OKLAHOMA  2015         671715       6184819
# 390         2015_OREGON         OREGON  2015         570376       7011609
# 391   2015_PENNSYLVANIA   PENNSYLVANIA  2015        1589429      29690645
# 392      2015_TENNESSEE      TENNESSEE  2015         994530       9562527
# 393          2015_TEXAS          TEXAS  2015        5004866      56255791
# 394           2015_UTAH           UTAH  2015         573913       4537962
# 395        2015_VERMONT        VERMONT  2015          85184       1969415
# 396       2015_VIRGINIA       VIRGINIA  2015        1279867      16113212
# 397     2015_WASHINGTON     WASHINGTON  2015        1072359      13630138
# 398      2015_WISCONSIN      WISCONSIN  2015         861813      11553677
# 399        2015_WYOMING        WYOMING  2015          93867       1942406
#
#      prisoner_count  corr_total_exp  state_population  cost_per_stu  \
# 360         25212.0          742594           4858979     10.206890
# 361          5247.0          346872            738432     22.701549
# 362         42204.0         1708409           6828065      8.362734
# 363         15784.0          587690           2978204     11.154354
# 364        127815.0        15275175          39144818     12.585830
# 365         19959.0         1316236           5456574     10.956624
# 366         16024.0          699051           3590886     20.861449
# 367          6437.0          302261            945934     16.209881
# 368         99485.0         4125808          20271272      9.941916
# 369         52002.0         2278830          10214860     10.770200
# 370          5413.0          217301           1431603     13.822506
# 371          7238.0          340056           1654930      7.403468
# 372         46240.0         2254133          12859995     15.831991
# 373         26586.0         1020450           6619680     11.330805
# 374          8864.0          443845           3123899     13.402942
# 375          9533.0          513474           2911641     12.428005
# 376         11959.0          797319           4425092     10.973364
# 377         18447.0         1138255           4670724     12.764102
# 378          2190.0          210657           1329328     14.736286
# 379         20951.0         1864705           6006401     15.882274
# 380          9493.0         1102746           6794422     18.526103
# 381         42628.0         2496266           9922576     13.191661
# 382          9578.0          939218           5489594     14.831746
# 383         13967.0          497701           2992333      9.434196
# 384         32295.0          953771           6083672     11.806229
# 385          3176.0          268128           1032949     12.494832
# 386          5133.0          471788           1896190     13.717921
# 387         13235.0          678562           2890845      9.529796
# 388         52240.0         1971480          11613423     14.099124
# 389         27321.0          746089           3911338      9.207505
# 390         14655.0         1129757           4028977     12.292959
# 391         48846.0         3416695          12802503     18.680070
# 392         19800.0         1161777           6600299      9.615122
# 393        152492.0         5831665          27469114     11.240219
# 394          4831.0          528622           2995919      7.907056
# 395          1750.0          143436            626042     23.119541
# 396         30430.0         2472309           8382993     12.589755
# 397         17222.0         1677560           7170351     12.710424
# 398         22914.0         1540158           5771337     13.406246
# 399          2400.0          213887            586107     20.693172
#
#      stu_to_pop_percent  cost_per_prisoner  prisoner_to_pop_percent
# 360            0.151261          29.453990                 0.005189
# 361            0.177071          66.108634                 0.007106
# 362            0.138396          40.479789                 0.006181
# 363            0.161064          37.233274                 0.005300
# 364            0.159064         119.510034                 0.003265
# 365            0.159866          65.946991                 0.003658
# 366            0.140736          43.625250                 0.004462
# 367            0.128809          46.956812                 0.006805
# 368            0.135346          41.471659                 0.004908
# 369            0.168167          43.821968                 0.005091
# 370            0.127398          40.144282                 0.003781
# 371            0.165645          46.982039                 0.004374
# 372            0.159185          48.748551                 0.003596
# 373            0.151701          38.382984                 0.004016
# 374            0.161757          50.072766                 0.002837
# 375            0.170667          53.862792                 0.003274
# 376            0.155584          66.671043                 0.002703
# 377            0.141523          61.704071                 0.003949
# 378            0.132530          96.190411                 0.001647
# 379            0.145529          89.003150                 0.003488
# 380            0.134836         116.164121                 0.001397
# 381            0.135550          58.559304                 0.004296
# 382            0.147013          98.059929                 0.001745
# 383            0.163815          35.634066                 0.004668
# 384            0.146750          29.533086                 0.005308
# 385            0.139839          84.423174                 0.003075
# 386            0.164689          91.912722                 0.002707
# 387            0.151841          51.270268                 0.004578
# 388            0.137791          37.738897                 0.004498
# 389            0.171735          27.308261                 0.006985
# 390            0.141568          77.090208                 0.003637
# 391            0.124150          69.948307                 0.003815
# 392            0.150680          58.675606                 0.003000
# 393            0.182200          38.242432                 0.005551
# 394            0.191565         109.422894                 0.001613
# 395            0.136068          81.963429                 0.002795
# 396            0.152674          81.245777                 0.003630
# 397            0.149555          97.407967                 0.002402
# 398            0.149326          67.214716                 0.003970
# 399            0.160153          89.119583                 0.004095

# %% [markdown]
# ## SQL Connection

# %%
eng = create_engine('postgresql+psycopg2://'+ username +':' + pgpass + '@' +host_loc + ':' + cred_port + '/' + db)
conn = eng.connect()

# %%
print(eng.table_names())
# Out:
# ['incarceration', 'ed_enroll_exp', 'prisoner_exp', 'fourth_grade_read', 'ed_corr_data']

# %%
incarceration_df.to_sql(name='incarceration', con=eng, if_exists='append', index=False)

# %%
ed_enroll_exp_df.to_sql(name='ed_enroll_exp', con=eng, if_exists='append', index=False)

# %%
prisoner_exp_df.to_sql(name='prisoner_exp', con=eng, if_exists='append', index=False)

# %%
fourth_grade_read_df.to_sql(name='fourth_grade_read', con=eng, if_exists='append', index=False)

# %%
ed_corr_data_df.to_sql(name='ed_corr_data', con=eng, if_exists='append', index=False)
